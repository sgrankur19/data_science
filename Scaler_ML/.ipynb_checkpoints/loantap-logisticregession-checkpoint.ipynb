# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('logistic_regression.csv')

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %% [markdown]
# Data dictionary:
#
# loan_amnt : The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.
#
# term : The number of payments on the loan. Values are in months and can be either 36 or 60.
#
# int_rate : Interest Rate on the loan
#
# installment : The monthly payment owed by the borrower if the loan originates.
#
# grade : LoanTap assigned loan grade
#
# sub_grade : LoanTap assigned loan subgrade
#
# emp_title : The job title supplied by the Borrower when applying for the loan.
#
# emp_length : Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.
#
# home_ownership : The home ownership status provided by the borrower during registration or obtained from the credit report.
#
# annual_inc : The self-reported annual income provided by the borrower during registration.
#
# verification_status : Indicates if income was verified by LoanTap, not verified, or if the income source was verified
#
# issue_d : The month which the loan was funded
#
# loan_status : Current status of the loan - Target Variable
#
# purpose : A category provided by the borrower for the loan request.
#
# title : The loan title provided by the borrower
#
# dti : A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LoanTap loan, divided by the borrower’s self-reported monthly income.
#
# earliest_cr_line : The month the borrower's earliest reported credit line was opened
#
# open_acc : The number of open credit lines in the borrower's credit file.
#
# pub_rec : Number of derogatory public records
#
# revol_bal : Total credit revolving balance
#
# revol_util : Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.
#
# total_acc : The total number of credit lines currently in the borrower's credit file
#
# initial_list_status : The initial listing status of the loan. Possible values are – W, F
#
# application_type : Indicates whether the loan is an individual application or a joint application with two co-borrowers
#
# mort_acc : Number of mortgage accounts.
#
# pub_rec_bankruptcies : Number of public record bankruptcies
#
# Address: Address of the individual

# %%
df.shape
# Out:
# (396030, 27)

# %% [markdown]
# Lets look at the columns

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'application_type',
#        'mort_acc', 'pub_rec_bankruptcies', 'address'],
#       dtype='object')

# %%
df.describe()
# Out:
#            loan_amnt       int_rate    installment    annual_inc  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean    14113.888089      13.639400     431.849698  7.420318e+04
# std      8357.441341       4.472157     250.727790  6.163762e+04
# min       500.000000       5.320000      16.080000  0.000000e+00
# 25%      8000.000000      10.490000     250.330000  4.500000e+04
# 50%     12000.000000      13.330000     375.430000  6.400000e+04
# 75%     20000.000000      16.490000     567.300000  9.000000e+04
# max     40000.000000      30.990000    1533.810000  8.706582e+06
#
#                  dti       open_acc        pub_rec     revol_bal  \
# count  396030.000000  396030.000000  396030.000000  3.960300e+05
# mean       17.379514      11.311153       0.178191  1.584454e+04
# std        18.019092       5.137649       0.530671  2.059184e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
num_col = ['loan_amnt','int_rate','installment','annual_inc','dti','open_acc','pub_rec','revol_bal','revol_util','total_acc','mort_acc','pub_rec_bankruptcies']

# %%
cat_col = [ 'term', 'grade', 'sub_grade','emp_title', 'emp_length', 'home_ownership',
       'verification_status', 'issue_d','purpose', 'title', 
       'earliest_cr_line','initial_list_status', 'application_type','address']

# %% [markdown]
# ### Categorical Variable Analysis

# %%
cat_col_df = df[cat_col]
cat_col_df.head()
# Out:
#          term grade sub_grade                emp_title emp_length  \
# 0   36 months     B        B4                Marketing  10+ years
# 1   36 months     B        B5          Credit analyst     4 years
# 2   36 months     B        B3             Statistician   < 1 year
# 3   36 months     A        A2          Client Advocate    6 years
# 4   60 months     C        C5  Destiny Management Inc.    9 years
#
#   home_ownership verification_status   issue_d             purpose  \
# 0           RENT        Not Verified  Jan-2015            vacation
# 1       MORTGAGE        Not Verified  Jan-2015  debt_consolidation
# 2           RENT     Source Verified  Jan-2015         credit_card
# 3           RENT        Not Verified  Nov-2014         credit_card
# 4       MORTGAGE            Verified  Apr-2013         credit_card
#
#                      title earliest_cr_line initial_list_status  \
# 0                 Vacation         Jun-1990                   w
# ...

# %%
cat_col_df['emp_title'].value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %%
cat_col_df['emp_title'].nunique()
# Out:
# 173105

# %%
cat_col_df['term'].value_counts()
# Out:
# term
# 36 months    302005
# 60 months     94025
# Name: count, dtype: int64

# %%
cat_col_df['grade'].value_counts()
# Out:
# grade
# B    116018
# C    105987
# A     64187
# D     63524
# E     31488
# F     11772
# G      3054
# Name: count, dtype: int64

# %%
cat_col_df['sub_grade'].value_counts()
# Out:
# sub_grade
# B3    26655
# B4    25601
# C1    23662
# C2    22580
# B2    22495
# B5    22085
# C3    21221
# C4    20280
# B1    19182
# A5    18526
# C5    18244
# D1    15993
# A4    15789
# D2    13951
# D3    12223
# D4    11657
# A3    10576
# A1     9729
# D5     9700
# A2     9567
# E1     7917
# E2     7431
# E3     6207
# E4     5361
# E5     4572
# F1     3536
# F2     2766
# F3     2286
# F4     1787
# F5     1397
# G1     1058
# G2      754
# G3      552
# G4      374
# G5      316
# Name: count, dtype: int64

# %%
cat_col_df['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    126041
# 2 years       35827
# < 1 year      31725
# 3 years       31665
# 5 years       26495
# 1 year        25882
# 4 years       23952
# 6 years       20841
# 7 years       20819
# 8 years       19168
# 9 years       15314
# Name: count, dtype: int64

# %%
cat_col_df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: count, dtype: int64

# %%
cat_col_df['verification_status'].value_counts()
# Out:
# verification_status
# Verified           139563
# Source Verified    131385
# Not Verified       125082
# Name: count, dtype: int64

# %%
cat_col_df['issue_d'].value_counts()
# Out:
# issue_d
# Oct-2014    14846
# Jul-2014    12609
# Jan-2015    11705
# Dec-2013    10618
# Nov-2013    10496
#             ...
# Jul-2007       26
# Sep-2008       25
# Nov-2007       22
# Sep-2007       15
# Jun-2007        1
# Name: count, Length: 115, dtype: int64

# %%
cat_col_df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    234507
# credit_card            83019
# home_improvement       24030
# other                  21185
# major_purchase          8790
# small_business          5701
# car                     4697
# medical                 4196
# moving                  2854
# vacation                2452
# house                   2201
# wedding                 1812
# renewable_energy         329
# educational              257
# Name: count, dtype: int64

# %%
cat_col_df['title'].value_counts()
# Out:
# title
# Debt consolidation            152472
# Credit card refinancing        51487
# Home improvement               15264
# Other                          12930
# Debt Consolidation             11608
#                                ...
# Graduation/Travel Expenses         1
# Daughter's Wedding Bill            1
# gotta move                         1
# creditcardrefi                     1
# Toxic Debt Payoff                  1
# Name: count, Length: 48816, dtype: int64

# %%
cat_col_df['earliest_cr_line'].value_counts()
# Out:
# earliest_cr_line
# Oct-2000    3017
# Aug-2000    2935
# Oct-2001    2896
# Aug-2001    2884
# Nov-2000    2736
#             ...
# Jul-1958       1
# Nov-1957       1
# Jan-1953       1
# Jul-1955       1
# Aug-1959       1
# Name: count, Length: 684, dtype: int64

# %%
cat_col_df['initial_list_status'].value_counts()
# Out:
# initial_list_status
# f    238066
# w    157964
# Name: count, dtype: int64

# %%
cat_col_df['application_type'].value_counts()
# Out:
# application_type
# INDIVIDUAL    395319
# JOINT            425
# DIRECT_PAY       286
# Name: count, dtype: int64

# %% [markdown]
# ### Categorical Column Summary
#
# * There are 17 columns
# * loan_status - Target
# * Binary columns - initial_list_status(f/w), term(36 months, 60 months)
# * 6 types of home ownerships
# * There are 7 grades (A-G) and 35  (5 in each grade) subgrades
# * There are 11 employee lengths
# * 14 purpose
# * 115 issue_d
# * 684 earliest_cr_line
# * 48816 titles
# * There are 173105 employee titles
# * Address will be unique for each applicant
#
#
# Ordinal columns : grade, subgrade,emp_length, term

# %% [markdown]
# ### Numerical Variable Analysis

# %%
num_col_df = df[num_col]
num_col_df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  open_acc  pub_rec  \
# 0    10000.0     11.44       329.48    117000.0  26.24      16.0      0.0
# 1     8000.0     11.99       265.68     65000.0  22.05      17.0      0.0
# 2    15600.0     10.49       506.97     43057.0  12.79      13.0      0.0
# 3     7200.0      6.49       220.65     54000.0   2.60       6.0      0.0
# 4    24375.0     17.27       609.33     55000.0  33.95      13.0      0.0
#
#    revol_bal  revol_util  total_acc  mort_acc  pub_rec_bankruptcies
# 0    36369.0        41.8       25.0       0.0                   0.0
# 1    20131.0        53.3       27.0       3.0                   0.0
# 2    11987.0        92.2       26.0       0.0                   0.0
# 3     5472.0        21.5       13.0       0.0                   0.0
# 4    24584.0        69.8       43.0       1.0                   0.0

# %%
sns.kdeplot(data = num_col_df, x = 'loan_amnt')
plt.show()

# %% [markdown]
# * Most loans were applied for 10,000.
# * Loam amount lies in range (0-40000)

# %%
sns.kdeplot(data = num_col_df, x = 'int_rate')
plt.show()

# %% [markdown]
# * interest rate lies in range (3,30)
# * Most loans were given at 12-15% interest rate

# %%
sns.kdeplot(data = num_col_df, x = 'installment')
plt.show()

# %% [markdown]
# * Installment mostly is 300

# %%
sns.kdeplot(data = num_col_df, x = 'annual_inc')
plt.show()

# %%
sns.kdeplot(data = num_col_df, x = 'dti')
plt.show()

# %%
sns.kdeplot(data = num_col_df, x = 'open_acc')
plt.show()

# %%
sns.kdeplot(data = num_col_df, x = 'pub_rec')
plt.show()

# %%
sns.kdeplot(data = num_col_df, x = 'revol_bal')
plt.show()

# %% [markdown]
# Total credit revolving balance is mostly lying in 0.00 - 0.10 range

# %%
sns.kdeplot(data = num_col_df, x = 'revol_util')
plt.show()

# %% [markdown]
# The amount of credit the borrower is using relative to all available revolving credit lies in range 0-110

# %%
sns.kdeplot(data = num_col_df, x = 'total_acc')
plt.show()

# %% [markdown]
# * total account lie in range 0-80

# %%
sns.kdeplot(data = num_col_df, x = 'mort_acc')
plt.show()

# %% [markdown]
# Loan applicants mostly had morgage account 0, where as the ones who did lied in range of 1 to 12

# %%
sns.kdeplot(data = num_col_df, x = 'pub_rec_bankruptcies')
plt.show()

# %% [markdown]
# pub_rec_bankruptcies lie mostly in 0 and few in 1

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# Lets look at the impact categorical columns are creating

# %%
sns.countplot(data = df, x = 'initial_list_status', hue = 'loan_status')
# Out:
# <Axes: xlabel='initial_list_status', ylabel='count'>

# %% [markdown]
# People with initial list status
# * fully paid f have more more than w
# * Charged off was also slightly higher for f as compard to w

# %% [markdown]
# Lets look how term is affecting loan_status

# %%
sns.countplot(data = df, x = 'term', hue = 'loan_status')
# Out:
# <Axes: xlabel='term', ylabel='count'>

# %% [markdown]
# Fully paid mostly lied mostly on 36 months term.

# %%
sns.countplot(data = df,x = 'home_ownership', hue = 'loan_status')
# Out:
# <Axes: xlabel='home_ownership', ylabel='count'>

# %% [markdown]
# * Top 3 ownerships in terms of fully paid loan status are:
#  Mortgage, Rent, Own
# * Charged off categories:
#  Rent, Mortgage, Own

# %%
ax = sns.countplot(data = df,x = 'grade', hue = 'loan_status',order = df['grade'].value_counts().index)

# %% [markdown]
# Fully paid:
# B > C > A > D > E > F > G
#
# Charged off:
# C > D > B > E > F > A > G

# %%
ax = sns.countplot(data = df,x = 'emp_length', hue = 'loan_status', order = df['emp_length'].value_counts().index)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# * We can breakdown this category as 2 buckets: <10 and >10

# %%
ax = sns.countplot(data = df,x = 'purpose', hue = 'loan_status',order = df['purpose'].value_counts().index)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Top 3 applicants and their fully paid order:
# * debt_consolidation had highest applications.
# * credit-ard had second highest applicants
# * home_improvement and other had approximately similar applicants

# %%
ax = sns.countplot(data = df,x = 'sub_grade', hue = 'loan_status',order = df['sub_grade'].value_counts().index)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * B and C have highest fully paid population.
# * A4 is highest
# * E,F,G have lowest numbee of applicants.

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.figure(figsize=(10,10))
corr = num_col_df.corr()
sns.heatmap(data = corr, annot = True, cmap = 'crest')
# Out:
# <Axes: >

# %% [markdown]
# * We can consider either of installment or loan_amt.
# * pub_rec_bankruptcies and pub_rec are also corelatted.
# * total_acc and open_acc are also corelated
# * Lets drop either of each.

# %%
num_col_df.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  open_acc  pub_rec  \
# 0    10000.0     11.44       329.48    117000.0  26.24      16.0      0.0
# 1     8000.0     11.99       265.68     65000.0  22.05      17.0      0.0
# 2    15600.0     10.49       506.97     43057.0  12.79      13.0      0.0
# 3     7200.0      6.49       220.65     54000.0   2.60       6.0      0.0
# 4    24375.0     17.27       609.33     55000.0  33.95      13.0      0.0
#
#    revol_bal  revol_util  total_acc  mort_acc  pub_rec_bankruptcies
# 0    36369.0        41.8       25.0       0.0                   0.0
# 1    20131.0        53.3       27.0       3.0                   0.0
# 2    11987.0        92.2       26.0       0.0                   0.0
# 3     5472.0        21.5       13.0       0.0                   0.0
# 4    24584.0        69.8       43.0       1.0                   0.0

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Handling Missing Values

# %%
df.isna().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# dtype: int64

# %%
col = ['title','emp_length','emp_title']
for each in col:
    df[each].fillna(value=df[each].mode()[0],inplace=True)
# Out:
# /var/folders/qp/g8gjs5xx2937j_gh9pqg5cgc0000gn/T/ipykernel_7600/3927605046.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[each].fillna(value=df[each].mode()[0],inplace=True)

# %%
mean_col = ['revol_util','mort_acc','pub_rec_bankruptcies']
for each in mean_col:
    df[each].fillna(value=df[each].mean(),inplace=True)
# Out:
# /var/folders/qp/g8gjs5xx2937j_gh9pqg5cgc0000gn/T/ipykernel_7600/3819688880.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[each].fillna(value=df[each].mean(),inplace=True)

# %% [markdown]
# ## Converting categorical to numerical column

# %% [markdown]
# Replacing all values <10 as 0 and 10+ as 1 in emp_length column

# %%
df.loc[df["emp_length"] != "10+ years", "emp_length"] = 0

# %%
df.loc[df["emp_length"] == "10+ years", "emp_length"] = 1

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'])
df['issue_year'] = df['issue_d'].dt.year
df['issue_month'] = df['issue_d'].dt.month
df.head()
# Out:
# /var/folders/qp/g8gjs5xx2937j_gh9pqg5cgc0000gn/T/ipykernel_7600/2104587895.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['issue_d'] = pd.to_datetime(df['issue_d'])
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing          1           RENT    117000.0  ...
# 1          Credit analyst           0       MORTGAGE     65000.0  ...
# ...

# %% [markdown]
# Dropping columns that:
# * are numerical but have positive corelation
# * are categorical but are adding no extra information

# %%
df.drop(columns = ['installment','pub_rec_bankruptcies', 'open_acc','issue_d','earliest_cr_line','title','emp_title','address','sub_grade'],axis = 1, inplace = True)

# %%
df['term'] = df.term.str.replace(' months','').astype(int)

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df['grade']= label_encoder.fit_transform(df['grade']) 
df['grade'].unique()
# Out:
# array([1, 0, 2, 4, 3, 5, 6])

# %%
df.head()
# Out:
#    loan_amnt  term  int_rate  grade emp_length home_ownership  annual_inc  \
# 0    10000.0    36     11.44      1          1           RENT    117000.0
# 1     8000.0    36     11.99      1          0       MORTGAGE     65000.0
# 2    15600.0    36     10.49      1          0           RENT     43057.0
# 3     7200.0    36      6.49      0          0           RENT     54000.0
# 4    24375.0    60     17.27      2          0       MORTGAGE     55000.0
#
#   verification_status  loan_status             purpose    dti  pub_rec  \
# 0        Not Verified   Fully Paid            vacation  26.24      0.0
# 1        Not Verified   Fully Paid  debt_consolidation  22.05      0.0
# 2     Source Verified   Fully Paid         credit_card  12.79      0.0
# 3        Not Verified   Fully Paid         credit_card   2.60      0.0
# 4            Verified  Charged Off         credit_card  33.95      0.0
#
#    revol_bal  revol_util  total_acc initial_list_status application_type  \
# ...

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: count, dtype: int64

# %%
df['verification_status'].value_counts()
# Out:
# verification_status
# Verified           139563
# Source Verified    131385
# Not Verified       125082
# Name: count, dtype: int64

# %% [markdown]
# Lets replace not verified - 0, verified - 1, Source verified - 2

# %%
df.loc[df['verification_status']=='Not Verified','verification_status'] = 0
df.loc[df['verification_status']=='Verified','verification_status'] = 1
df.loc[df['verification_status']=='Source Verified','verification_status'] = 2

# %% [markdown]
# Replacing charged off as 0 and fully paid as 1

# %%
df.loc[df['loan_status']=='Fully Paid','loan_status']=1
df.loc[df['loan_status']=='Charged Off','loan_status']=0

# %% [markdown]
# Putting initial list status : w(whole) - 1, f (fractional) - 0

# %%
df.loc[df['initial_list_status']=='w','initial_list_status'] = 1
df.loc[df['initial_list_status']=='f','initial_list_status'] = 0

# %%
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    234507
# credit_card            83019
# home_improvement       24030
# other                  21185
# major_purchase          8790
# small_business          5701
# car                     4697
# medical                 4196
# moving                  2854
# vacation                2452
# house                   2201
# wedding                 1812
# renewable_energy         329
# educational              257
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting the dataset

# %%
X = df.drop(columns = 'loan_status')
y = df['loan_status'].astype('int')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   loan_amnt            396030 non-null  float64
#  1   term                 396030 non-null  int64
#  2   int_rate             396030 non-null  float64
#  3   grade                396030 non-null  int64
#  4   emp_length           396030 non-null  object
#  5   home_ownership       396030 non-null  object
#  6   annual_inc           396030 non-null  float64
#  7   verification_status  396030 non-null  object
#  8   purpose              396030 non-null  object
#  9   dti                  396030 non-null  float64
#  10  pub_rec              396030 non-null  float64
#  11  revol_bal            396030 non-null  float64
#  12  revol_util           396030 non-null  float64
#  13  total_acc            396030 non-null  float64
# ...

# %%
from sklearn.model_selection import train_test_split
X_train_val,X_test,y_train_val,y_test = train_test_split(X,y,random_state=True, test_size = 0.2)
X_train,X_val,y_train,y_val = train_test_split(X,y,random_state=True, test_size = 0.25)

# %% [markdown]
# Lets convert verification status

# %% [markdown]
# ## Nominal category column conversion

# %%
import category_encoders as ce

# Initialize and fit the target encoder
encoder = ce.TargetEncoder(cols=['application_type', 'home_ownership', 'purpose'])
encoder.fit_transform(X_train, y_train)
# Transform both training and testing sets
X_train_encoded = encoder.transform(X_train)
X_test_encoded = encoder.transform(X_test)
X_val_encoded = encoder.transform(X_val)

# %% [markdown]
# Now that we have all numerical columns, lets train our model

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_encoded)

X_train = scaler.transform(X_train_encoded)
X_val = scaler.transform(X_val_encoded)
X_test = scaler.transform(X_test_encoded)

# %%
from sklearn.linear_model import LogisticRegression  
model= LogisticRegression()  
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[-0.06278316, -0.18469667, -0.08967224, -0.36575685, -0.01437961,
#          0.11726617,  0.18671761, -0.05775546,  0.05591057, -0.49796263,
#         -0.03230017,  0.03883259, -0.0772723 ,  0.02974275,  0.01877572,
#         -0.00517635,  0.08571469, -0.06988225,  0.03126532]])

# %%
model.intercept_
# Out:
# array([1.57648542])

# %%
y_pred = model.predict(X_val)
np.mean(y_pred==y_val)
model.score(X_val,y_val)
# Out:
# 0.8042582417582418

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.pipeline import make_pipeline
train_scores = []
val_scores = []

for lam in np.arange(0.01,500,10):
    scaled_lr = make_pipeline(StandardScaler(),LogisticRegression(C=1/lam))
    scaled_lr.fit(X_train,y_train)
    train_score = scaled_lr.score(X_train, y_train)
    val_score = scaled_lr.score(X_val, y_val)
    train_scores.append(train_score)
    val_scores.append(val_score)
    
plt.figure(figsize=(10,5))
plt.plot(list(np.arange(0.01,500,10)),train_scores,label='train')
plt.plot(list(np.arange(0.01,500,10)),val_scores,label='val')


plt.legend(loc='lower right')
plt.xlabel('Regularization Parameter')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

# %% [markdown]
# Lets consider lambda as 60 and retrain our regression model.

# %%
model=LogisticRegression(C=1/60)
model.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.016666666666666666)

# %%
model.coef_
# Out:
# array([[-0.06258192, -0.18465348, -0.09341868, -0.36208402, -0.01433667,
#          0.11710657,  0.18687667, -0.0577948 ,  0.05589484, -0.4930802 ,
#         -0.03218663,  0.03837931, -0.07736937,  0.02918246,  0.01862478,
#         -0.00500996,  0.08589854, -0.07033021,  0.0311771 ]])

# %%
model.intercept_
# Out:
# array([1.57607941])

# %% [markdown]
# # Model Performance

# %%
def accuracy(y_true, y_pred):
  return np.sum(y_true==y_pred)/y_true.shape[0]

# %%
accuracy(y_train,model.predict(X_train))
# Out:
# np.float64(0.8053915198200806)

# %%
accuracy(y_val, model.predict(X_val))
# Out:
# np.float64(0.8042885423400129)

# %%
accuracy(y_test, model.predict(X_test))
# Out:
# np.float64(0.8039289952781355)

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Here false positive is more critical than true negative: which means faulter labelled as non faulter is more critical than non faulter categorised as faulter.
# Hence we will choose sensitivity

# %%
from sklearn.metrics import  confusion_matrix, ConfusionMatrixDisplay
conf = confusion_matrix(y_test, model.predict(X_test))
disp = ConfusionMatrixDisplay(confusion_matrix=conf,display_labels=model.classes_)
disp.plot()

# %%
sensitivity = 62514/(1042+62514)
sensitivity
# Out:
# 0.9836050097551765

# %%
from sklearn.metrics import precision_score, f1_score
precision_score(y_test, y_pred)
# Out:
# 0.8118409433276194

# %%
f1_score(y_test,y_pred)
# Out:
# 0.889513375071144

# %%
from sklearn.metrics import roc_curve
prob = model.predict_proba(X_test)
probabilities  = prob[:,1]
fpr,tpr,thres = roc_curve(y_test, probabilities)
plt.plot(fpr,tpr)

# %% [markdown]
# # Insights:
# * People with more than 10 years of employment tend to fully pay loan
# * Interest rates generally lie : 12-15%

# %% [markdown]
# # Recommendations:
# * Loantap should focus on betterment of low grade loans as probability of paying back G grade loans are approximately 55 %, one out of two loans are going to get charged off.
# *  Loantap should specially keep track on the loans that has high interest paying loans as there are 40% chance to make a default.
# * Loantap should promote low interest loans as much as possible as probability of paying back the loans are above 90%.
# * Loantap should promote joint loans as much as possible as it has the highest probability of getting fully paid among all categories. As there are high numbers of public derogatory records the chances of making default increases, thus loantap should avoid paying loans to such user
